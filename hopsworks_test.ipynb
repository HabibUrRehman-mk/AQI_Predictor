# %%
# import os
# import hopsworks

# # 1. Retrieve your API key
# api_key = os.getenv("HOPSWORKS_API_KEY")

# # 2. Establish a connection without selecting a project
# conn = hopsworks.connection(api_key_value=api_key)

# # 3. Create a new project programmatically
# project_name = "AQI_Predictor"  # Standard characters: letters, numbers, _, .
# project = conn.create_project(
#     name=project_name, 
#     description="AQI Predictor of Faisalabad, Punjab, Pakistan as End to End Project for 10Pearls Summer Internship"
# )

# print(f"Successfully created project: {project.name}")

# # 4. Get the Feature Store for your new project
# fs = project.get_feature_store()
